# %% [markdown]
# # Ejercicio 1 Kata 5

# %%
# Lista de planetas 

Mercurio =	57900000
Venus =	108200000
Tierra =	149600000
Marte = 	227900000
Júpiter =	778600000
Saturno =	1433500000
Urano =	2872500000
Neptuno =	4495100000

# Creacion de variables

primero = Mercurio
segundo = Venus

# Calcular la disctanica entre ellos

distanciaKM= segundo - primero 
print(distanciaKM)

distanciaMILLAS = distanciaKM * 0.621
print(distanciaMILLAS)
# Out:
# 50300000

# %% [markdown]
# # Ejercicio 2 Kata 5

# %%
# Entradas del usuario

primerplaneta = input("Dame la distancia de tu primer planeta en KM")
segundoplaneta = input("Dame la distancia de tu segundo planeta en KM")

# Conversion de cadenas

primerplaneta = int(primerplaneta)
segundoplaneta = int(segundoplaneta)

distancia_del_usuario = segundoplaneta - primerplaneta
print(distancia_del_usuario)


# La distancia pero en millas

distancia_en_millas = distancia_del_usuario * 0.621
print(distancia_en_millas)
# Out:
# -37
# -22.977
