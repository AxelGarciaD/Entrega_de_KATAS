# %% [markdown]
# # Apunte

# %%
fact = 'The Moon has no atmosphere.'
fact + 'No sound can be heard on the Moon.'
# Out:
# 'The Moon has no atmosphere.No sound can be heard on the Moon.'

# %%
print (fact)
fact
# Out:
# The Moon has no atmosphere.
# 'The Moon has no atmosphere.'

# %%
two_facts = fact + 'No sound can be heard on the Moon.'
two_facts

#Nos podemos ahorrar la palabra print cuando solo poneos el nombre de la variable

# %%
#Se puede ocupar cualquier tpo de comilla para las cadenas de textos, pero cuando queremos usar 2 comillas es importante usar distintas 

'The "near side" is the part of the Moon that faces the Earth'

# %%
#Se debe de tener cuidado para no generar un error 
'We only see about 60% of the Moon's surface'
  File '<stdin>', line 1
    'We only see about 60% of the Moon's surface'
# Out:
#   Input In [4]
#     'We only see about 60% of the Moon's surface'
#                                                 ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
'temperatures and facts about the moon'.title()
# Out:
# 'Temperatures And Facts About The Moon'

# %% [markdown]
# # KATA 4 SOLUCION

# %% [markdown]
# # Ejercicio 1

# %%
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth.","On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highest daylight temperature of the Moon is 127 C."""

partes = text .split('. ')
partes
# Out:
# ['Interesting facts about the Moon',
#  "The Moon is Earth's only satellite",
#  'There are several interesting facts about the Moon and how it affects life here on Earth.","On average, the Moon moves 4cm away from the Earth every year',
#  'This yearly drift is not significant enough to cause immediate effects on Earth',
#  'The highest daylight temperature of the Moon is 127 C.']

# %% [markdown]
# # Define las palabras average, temperature y distance suenan bien

# %%
# Definir palabras claves

PClaves = ["average", "temperature", "distance"]

# %%
# Ciclo 1

for nosimporta in partes:
    for PClaves in PClaves:
        if PClaves in nosimporta:
            print(nosimporta)
# Out:
# Interesting facts about the Moon
# The Moon is Earth's only satellite
# There are several interesting facts about the Moon and how it affects life here on Earth.","On average, the Moon moves 4cm away from the Earth every year
# This yearly drift is not significant enough to cause immediate effects on Earth
# The highest daylight temperature of the Moon is 127 C.

# %%
# Ciclo 2
for contieneC in partes:
        if PClaves in contieneC:
            print(contieneC.replace(' C', ' Celsius'))
# Out:
# Interesting facts about the Moon
# The Moon is Earth's only satellite
# There are several interesting facts about the Moon and how it affects life here on Earth.","On average, the Moon moves 4cm away from the Earth every year
# This yearly drift is not significant enough to cause immediate effects on Earth
# The highest daylight temperature of the Moon is 127 Celsius.

# %% [markdown]
# # Ejercicio 2

# %%
# Datos 
nombre = "luna"
Gravedad = 0.00162 
planeta = "tierra" 

# Titulo

title = f'datos de gravedad sobre {nombre}'

# Plantillas
hechos = f"""{'-'*80} 
Nombre del planeta: {planeta} 
Gravedad en {nombre}: {Gravedad * 1000} m/s2 """

# Unión
template = f"""{title.title()} 
{hechos} 
""" 
print(hechos)
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: tierra
# Gravedad en luna: 1.6199999999999999 m/s2

# %%
# Nuevos datos muestra
planeta = 'Marte '
gravedad  = 0.00143
nombre = 'Ganímedes' 

print (hechos)
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: tierra
# Gravedad en luna: 1.6199999999999999 m/s2

# %% [markdown]
# # No supe hacer la segunda plantilla sin hacer una plantilla desde 0
