# %% [markdown]
# APUNTESSSS--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Prueba de print

# %%
# Impresión en pantalla 
print('Hola desde la consola')
# Out:
# Hola desde la consola

# %% [markdown]
# Prueba de suma

# %%
sum = 2 + 2
product = sum - 3
print(product)
print("Lo logre :D")
# Out:
# 1
# Lo logre :D

# %% [markdown]
# Tipos de variantes

# %%
#Se declara la variable 
distancia_a_alfa_centauri = 4.367
#Se descubre el tipo de variable 
print ("Es un.....", type(distancia_a_alfa_centauri))
# Out:
# Es un..... <class 'float'>

# %% [markdown]
# Fechas

# %%
#Importamos la biblioteca
from datetime import date
#Dia de hoy
date.today()
# Out:
# 2022-02-11

# %%
#Fecha de hoy pero con print
print(date.today())
# Out:
# 2022-02-11

# %%
# Tu turno ejecuta el siguiente comando: .
print("Today's date is: " + str(date.today()))

#Y hasta donde tengo entendido tambien se puede con coma
print("Today's date is: ",(date.today()))
# Out:
# Today's date is:  2022-02-11

# %% [markdown]
# Entrada del usuario

# %%
print("Bienvenido al programa de bienvenida")
name = input("Introduzca su nombre ")
print("Saludos: " + name)
# Out:
# Bienvenido al programa de bienvenida
# Saludos: AXel

# %% [markdown]
# Trabajando con numeros

# %%
print("Calculadora")
first_number = input("Primer número: ")
second_number = input("Segundo número: ")
print(first_number + second_number)

#El input solo es para caracteres de letras, no numeros
# Out:
# Calculadora
# 32

# %%
print("Calculadora")
first_number = input("Primer número: ")
second_number = input("Segundo número: ")
print(int(first_number) + int(second_number))

#El int nos ayuda a convertir de letras a numeros
# Out:
# Calculadora
# 7

# %% [markdown]
# EJERCICIO KATA 1--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Programa para la fecha

# %%
from datetime import date

print("La fecha del dia de hoy es",(date.today()))
# Out:
# La fecha del dia de hoy es 2022-02-11

# %% [markdown]
# Convertidor de unidades

# %%
print("Dime cuantos parsec quieres convertir")
parsec = input("Dame los parsec")

lightyears = 3.26156 #parsec

print("esos parsec son...", (int(parsec)*lightyears), "años luz")


#print(str(parsec) + "esos parsec son " + str(lightyears) + " lightyears")
# Out:
# Dime cuantos parsec quieres convertir
# esos parsec son... 35.877159999999996 años luz
