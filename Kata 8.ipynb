# %% [markdown]
# # Ejercicio 1 Kata 8

# %%
planet = {'name':'Mars','moons': 2}

print(f'{planet["name"]} tiene {planet["moons"]} moons')

# Se agregan las circunferencias 

planet ['circunferencia en KM'] = {
    'polar': 6752,
    'equatorial': 6792
}

print(f'{planet["name"]} has a polar circumference of {planet["circunferencia en KM"]["polar"]}')
# Out:
# Mars tiene 2 moons
# Mars has a polar circumference of 6752

# %% [markdown]
# # Ejercicio 2 Kata 8

# %%
# Lista de planetas y sus lunas

planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}

cantidad_de_lunas = planet_moons.values()

total_de_moons = sum(cantidad_de_lunas)  

print(total_de_moons)
# Out:
# 214
